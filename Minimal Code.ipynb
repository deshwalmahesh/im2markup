# %% [markdown]
# # Downloading the Required Dataset

# %%
# !mkdir dataset
# %cd dataset
# !wget http://lstm.seas.harvard.edu/latex/data/im2latex_validate_filter.lst
# !wget http://lstm.seas.harvard.edu/latex/data/im2latex_train_filter.lst
# !wget http://lstm.seas.harvard.edu/latex/data/im2latex_test_filter.lst
# !wget http://lstm.seas.harvard.edu/latex/data/formula_images_processed.tar.gz
# !wget http://lstm.seas.harvard.edu/latex/data/im2latex_formulas.norm.lst
# !tar -zxvf formula_images_processed.tar.gz 
# %cd ..
# Out:
# Streaming output truncated to the last 5000 lines.
# formula_images_processed/410b27570c.png
# formula_images_processed/787db8af51.png
# formula_images_processed/5591917116.png
# formula_images_processed/7f14ce8f69.png
# formula_images_processed/256b167327.png
# formula_images_processed/71500ed50a.png
# formula_images_processed/71620990cc.png
# formula_images_processed/5c355acac8.png
# formula_images_processed/1051679595.png
# formula_images_processed/32b2b8a061.png
# formula_images_processed/52082547a6.png
# formula_images_processed/561cde56ac.png
# formula_images_processed/e524371a37.png
# formula_images_processed/39a2035e7b.png
# formula_images_processed/657ff86419.png
# formula_images_processed/4b25c8f837.png
# formula_images_processed/115c24ae0c.png
# formula_images_processed/2e5ab7abc4.png
# formula_images_processed/430c94b6c5.png
# formula_images_processed/275732ecef.png
# formula_images_processed/6d0c3b1cca.png
# formula_images_processed/1ef1e76652.png
# formula_images_processed/21461a3038.png
# formula_images_processed/68549c2599.png
# formula_images_processed/388891d2b1.png
# formula_images_processed/7506f84be7.png
# formula_images_processed/6dbd6c4994.png
# formula_images_processed/82a9286014.png
# formula_images_processed/36386166eb.png
# formula_images_processed/48f9785ff1.png
# formula_images_processed/47da5bdc0d.png
# formula_images_processed/4a9d3d9de1.png
# formula_images_processed/7918b81ec7.png
# formula_images_processed/588fe4f670.png
# formula_images_processed/1ddcab2743.png
# formula_images_processed/3c5e16cde1.png
# formula_images_processed/5b405fae02.png
# formula_images_processed/2ebf18fdad.png
# formula_images_processed/300c2149a0.png
# formula_images_processed/8e0aea1264.png
# formula_images_processed/6c1b52774b.png
# formula_images_processed/1336a2d4c0.png
# formula_images_processed/7f815b2f71.png
# formula_images_processed/69b2f0599f.png
# formula_images_processed/278201f4e4.png
# formula_images_processed/6ca5ec2028.png
# formula_images_processed/14f6997ab6.png
# formula_images_processed/4bb41af0c8.png
# formula_images_processed/2190da0d3b.png
# formula_images_processed/b6efab7331.png
# formula_images_processed/1524b1bd79.png
# formula_images_processed/73c2a53a9b.png
# formula_images_processed/5a4ad1ab58.png
# formula_images_processed/119027fd4d.png
# formula_images_processed/4736fd69fa.png
# formula_images_processed/210241390e.png
# formula_images_processed/26f3008d72.png
# formula_images_processed/7603e364c3.png
# formula_images_processed/113762ada1.png
# formula_images_processed/64a1f415a4.png
# formula_images_processed/52d3c8ef86.png
# formula_images_processed/67a7642140.png
# formula_images_processed/3611d1ea60.png
# formula_images_processed/5e5cff9749.png
# formula_images_processed/681b9c61b8.png
# formula_images_processed/34e258b117.png
# formula_images_processed/64839b172c.png
# formula_images_processed/2be42d8cbb.png
# formula_images_processed/50b2ecf19e.png
# formula_images_processed/75518a26df.png
# formula_images_processed/5a3479e97a.png
# formula_images_processed/708e4eb8ee.png
# formula_images_processed/5947c4a4ee.png
# formula_images_processed/6219423dd5.png
# formula_images_processed/61e6cd496c.png
# formula_images_processed/2eb8651e2e.png
# formula_images_processed/361542c1c5.png
# formula_images_processed/4e164de2ed.png
# formula_images_processed/2f79ad6603.png
# formula_images_processed/32702a91c5.png
# formula_images_processed/59cd05f175.png
# formula_images_processed/28f7211888.png
# formula_images_processed/71125b5910.png
# formula_images_processed/4e6d33da41.png
# formula_images_processed/2be065204f.png
# formula_images_processed/3ee16e1041.png
# formula_images_processed/58e4f07fff.png
# formula_images_processed/5faaad368c.png
# formula_images_processed/4fa39afba9.png
# formula_images_processed/3b8ee11727.png
# formula_images_processed/73616cd7b8.png
# formula_images_processed/5ae8aad499.png
# formula_images_processed/10ef6ae205.png
# formula_images_processed/4db9617d4f.png
# formula_images_processed/438bca5ea1.png
# formula_images_processed/2e868ef5bb.png
# formula_images_processed/1211520e31.png
# formula_images_processed/36ac47befd.png
# formula_images_processed/727177e8f7.png
# formula_images_processed/56b734279e.png
# formula_images_processed/3b86ec7f2b.png
# formula_images_processed/4d9900ca06.png
# formula_images_processed/6ff72f5655.png
# formula_images_processed/65895c59e5.png
# formula_images_processed/7908cf7e79.png
# formula_images_processed/11ab677532.png
# formula_images_processed/9c3c18cca8.png
# formula_images_processed/37c9da8d5c.png
# formula_images_processed/16b9d48192.png
# formula_images_processed/548a2ec66f.png
# formula_images_processed/7ffca2d735.png
# formula_images_processed/5314565a4e.png
# formula_images_processed/6e5ab2c7f2.png
# formula_images_processed/7423f392f6.png
# formula_images_processed/1133e07be0.png
# formula_images_processed/2e1d8188b5.png
# formula_images_processed/7c79e058c1.png
# formula_images_processed/56eb270f34.png
# formula_images_processed/45145de872.png
# formula_images_processed/2d54680eea.png
# formula_images_processed/d50e51aff6.png
# formula_images_processed/7c58979e6b.png
# formula_images_processed/5acf78b4c9.png
# formula_images_processed/83b199dbf0.png
# formula_images_processed/5d92929239.png
# formula_images_processed/51b5e5411c.png
# formula_images_processed/1c17da6cc1.png
# formula_images_processed/4d0bdc15ce.png
# formula_images_processed/c7f7843fe7.png
# formula_images_processed/6eccdcd76f.png
# formula_images_processed/345da7d92f.png
# formula_images_processed/6396eb001f.png
# formula_images_processed/4e111c2bd9.png
# formula_images_processed/f70bd30025.png
# formula_images_processed/34bdc70ea0.png
# formula_images_processed/b4b8492fec.png
# formula_images_processed/5de7f80209.png
# formula_images_processed/71088eac8d.png
# formula_images_processed/4c5f67d242.png
# formula_images_processed/4ae0a2d8f5.png
# formula_images_processed/4701af9aa9.png
# formula_images_processed/16382faff1.png
# formula_images_processed/5087a3c050.png
# formula_images_processed/127ca041ef.png
# formula_images_processed/3449b5266c.png
# formula_images_processed/57e2bb2486.png
# formula_images_processed/53070c4f44.png
# formula_images_processed/3f0be0af1c.png
# formula_images_processed/85333c1c9f.png
# formula_images_processed/7da92b392d.png
# formula_images_processed/733c6a983b.png
# formula_images_processed/176929770c.png
# formula_images_processed/791c91c8f2.png
# formula_images_processed/42e2067689.png
# formula_images_processed/38d709a416.png
# formula_images_processed/707ff9f712.png
# formula_images_processed/2207cb8ffe.png
# formula_images_processed/258ca5af7d.png
# formula_images_processed/e5e0157eb7.png
# formula_images_processed/6806b46b4f.png
# formula_images_processed/7a8ea9f220.png
# formula_images_processed/7858dd4c8b.png
# formula_images_processed/19a59c7f31.png
# formula_images_processed/1ce668e679.png
# formula_images_processed/52a8cd9e12.png
# formula_images_processed/181bcfb7cb.png
# formula_images_processed/7fe48d0185.png
# formula_images_processed/3db8ffaf6a.png
# formula_images_processed/87f8aeca84.png
# formula_images_processed/608559d26b.png
# formula_images_processed/484c0abf68.png
# formula_images_processed/31930ac62d.png
# formula_images_processed/40d9688204.png
# formula_images_processed/4729faf3ff.png
# formula_images_processed/517adbea68.png
# formula_images_processed/651587f527.png
# formula_images_processed/47064cc6fd.png
# formula_images_processed/7612ef925d.png
# formula_images_processed/9c497ea2ef.png
# formula_images_processed/53696b22cc.png
# formula_images_processed/523adf96e3.png
# formula_images_processed/3601c4cc91.png
# formula_images_processed/404029a4ad.png
# formula_images_processed/6c7ec3037d.png
# formula_images_processed/6893399c73.png
# formula_images_processed/7318ec79cf.png
# formula_images_processed/1783df4b53.png
# formula_images_processed/16edf4f878.png
# formula_images_processed/4b31c3fc17.png
# formula_images_processed/7fd862c223.png
# formula_images_processed/6e144f3ad2.png
# formula_images_processed/43f26dce08.png
# formula_images_processed/2156391bff.png
# formula_images_processed/7fcc727f5e.png
# formula_images_processed/6cbb9ec78c.png
# formula_images_processed/4f3bc70265.png
# formula_images_processed/e1e784b907.png
# formula_images_processed/2cbdf89209.png
# formula_images_processed/4af0c9f9ab.png
# formula_images_processed/61d3a46bc8.png
# formula_images_processed/e26d936da5.png
# formula_images_processed/6c6ade05cf.png
# formula_images_processed/43ca5163bf.png
# formula_images_processed/4fa4e6da1f.png
# formula_images_processed/73c701e5fb.png
# formula_images_processed/342e4e115d.png
# formula_images_processed/448b6536d3.png
# formula_images_processed/47fa6935f3.png
# formula_images_processed/35e6f6e457.png
# formula_images_processed/7ed694a8ef.png
# formula_images_processed/2a670f5ea6.png
# formula_images_processed/204465a87d.png
# formula_images_processed/9e8f9d831d.png
# formula_images_processed/4992859882.png
# formula_images_processed/6687773d9f.png
# formula_images_processed/450b14e1b7.png
# formula_images_processed/4cb01b33a2.png
# formula_images_processed/445d46db4e.png
# formula_images_processed/74d740f1f2.png
# formula_images_processed/8f3748e911.png
# formula_images_processed/59fd1eae16.png
# formula_images_processed/3b8a4c7716.png
# formula_images_processed/f5853ac55c.png
# formula_images_processed/2a7e754f18.png
# formula_images_processed/5b32dfab77.png
# formula_images_processed/5864514faa.png
# formula_images_processed/3df451a51e.png
# formula_images_processed/6e93840d1a.png
# formula_images_processed/18e793b893.png
# formula_images_processed/7bfbc419f9.png
# formula_images_processed/78ad552209.png
# formula_images_processed/4d4b443bd3.png
# formula_images_processed/f902cb171c.png
# formula_images_processed/2e9a276df2.png
# formula_images_processed/47de5c00fd.png
# formula_images_processed/11a77a3d6e.png
# formula_images_processed/99b3d236b4.png
# formula_images_processed/622efa428b.png
# formula_images_processed/6aa2b37a6b.png
# formula_images_processed/62e2615c8a.png
# formula_images_processed/5a3d7f1633.png
# formula_images_processed/6fb4b97338.png
# formula_images_processed/1755489f8c.png
# formula_images_processed/58b5c4bcda.png
# formula_images_processed/5892939945.png
# formula_images_processed/58be4dbe02.png
# formula_images_processed/737d1f8cb7.png
# formula_images_processed/1899a17aca.png
# formula_images_processed/38266cd93f.png
# formula_images_processed/18d34685ba.png
# formula_images_processed/164cc8793b.png
# formula_images_processed/5c25ab6c43.png
# formula_images_processed/2454b7573f.png
# formula_images_processed/538ddfe428.png
# formula_images_processed/2cefd80c94.png
# formula_images_processed/29e72bc001.png
# formula_images_processed/162a83b5e1.png
# formula_images_processed/3cf0819493.png
# formula_images_processed/48004121fc.png
# formula_images_processed/4c3cf571c6.png
# formula_images_processed/3c9fb233d3.png
# formula_images_processed/5a4304680d.png
# formula_images_processed/300b2a8013.png
# formula_images_processed/59d2423ae8.png
# formula_images_processed/1bd3262c42.png
# formula_images_processed/7b95211107.png
# formula_images_processed/315d90af72.png
# formula_images_processed/43b7576014.png
# formula_images_processed/783f45a74a.png
# formula_images_processed/76a24c7c14.png
# formula_images_processed/102009b318.png
# formula_images_processed/7c9ed4169a.png
# formula_images_processed/5702d92ec6.png
# formula_images_processed/1268193271.png
# formula_images_processed/7939029789.png
# formula_images_processed/2f1a59a2a4.png
# formula_images_processed/719b5681e9.png
# formula_images_processed/4da0f2a39d.png
# formula_images_processed/3802e6661d.png
# formula_images_processed/1301eae45e.png
# formula_images_processed/7cff48cfdc.png
# formula_images_processed/1bd631fe86.png
# formula_images_processed/19ff5fe86d.png
# formula_images_processed/56f3dc484d.png
# formula_images_processed/388ab38bd3.png
# formula_images_processed/55b8a00050.png
# formula_images_processed/7f921f14b5.png
# formula_images_processed/65d1b34803.png
# formula_images_processed/2389441c4f.png
# formula_images_processed/32bf4efbd2.png
# formula_images_processed/31ef31045d.png
# formula_images_processed/6221ba2a34.png
# formula_images_processed/5ef1e67a1e.png
# formula_images_processed/3f8b5cb88a.png
# formula_images_processed/68506acc9a.png
# formula_images_processed/5b8728320a.png
# formula_images_processed/47230bb0e2.png
# formula_images_processed/6b6ec95412.png
# formula_images_processed/564832988d.png
# formula_images_processed/a4ef39b022.png
# formula_images_processed/35d21771fe.png
# formula_images_processed/3bea2f425a.png
# formula_images_processed/6b823064c0.png
# formula_images_processed/4dddb18035.png
# formula_images_processed/60835aefc1.png
# formula_images_processed/31d10244ff.png
# formula_images_processed/53dc86baf7.png
# formula_images_processed/5f7cc9c22f.png
# formula_images_processed/3dab5e6a5f.png
# formula_images_processed/18a7881fb4.png
# formula_images_processed/246ae16256.png
# formula_images_processed/2822a22271.png
# formula_images_processed/30f575bf18.png
# formula_images_processed/7f890d719f.png
# formula_images_processed/6c7d5744a2.png
# formula_images_processed/426c79e68a.png
# formula_images_processed/51f8d38278.png
# formula_images_processed/7231e40d75.png
# formula_images_processed/490c91812f.png
# formula_images_processed/7f5a71b2ac.png
# formula_images_processed/77c2830522.png
# formula_images_processed/1e0028fc68.png
# formula_images_processed/258b66c967.png
# formula_images_processed/6fbd065a00.png
# formula_images_processed/588ea6ab83.png
# formula_images_processed/7d99042505.png
# formula_images_processed/35c0ff92a3.png
# formula_images_processed/1f84a1fe95.png
# formula_images_processed/574c2290e4.png
# formula_images_processed/6a2d0e1ddf.png
# formula_images_processed/1ab7d17edc.png
# formula_images_processed/5027ff3387.png
# formula_images_processed/1798579268.png
# formula_images_processed/4491c8e665.png
# formula_images_processed/55c9fa616e.png
# formula_images_processed/a1532fed38.png
# formula_images_processed/36bae85d75.png
# formula_images_processed/4f0dee0d54.png
# formula_images_processed/3fd60234dc.png
# formula_images_processed/1db794bbcf.png
# formula_images_processed/5f21734edc.png
# formula_images_processed/522125c591.png
# formula_images_processed/1292b06a20.png
# formula_images_processed/33a5b41d6f.png
# formula_images_processed/148e4b9a22.png
# formula_images_processed/1a9da3ccd2.png
# formula_images_processed/64abc56f16.png
# formula_images_processed/7e11d43c34.png
# formula_images_processed/79a9e6a552.png
# formula_images_processed/79e190d49e.png
# formula_images_processed/72e913de97.png
# formula_images_processed/3ba01b0281.png
# formula_images_processed/2c57fcb2af.png
# formula_images_processed/6c720e9fc0.png
# formula_images_processed/4bddb0d692.png
# formula_images_processed/274604c0d8.png
# formula_images_processed/207b3b8bc3.png
# formula_images_processed/6eeca3996b.png
# formula_images_processed/cfd791e782.png
# formula_images_processed/31a6b7916c.png
# formula_images_processed/2a898dc987.png
# formula_images_processed/61be188a4d.png
# formula_images_processed/45f7854cb5.png
# formula_images_processed/5ea3bbbe71.png
# formula_images_processed/31da48685b.png
# formula_images_processed/677d70d127.png
# formula_images_processed/9cad4d9922.png
# formula_images_processed/50df384037.png
# formula_images_processed/d38aa7a79f.png
# formula_images_processed/7e7b2d9e5b.png
# formula_images_processed/1eb37894c1.png
# formula_images_processed/121736e52b.png
# formula_images_processed/155359350a.png
# formula_images_processed/4f955f8802.png
# formula_images_processed/7be6ec698a.png
# formula_images_processed/173172aed3.png
# formula_images_processed/66453d88c0.png
# formula_images_processed/5ac8553f89.png
# formula_images_processed/677a2f38be.png
# formula_images_processed/49c0ce61c6.png
# formula_images_processed/7c79ece5a0.png
# formula_images_processed/1d0983d54e.png
# formula_images_processed/1b3fddb27b.png
# formula_images_processed/33c2032348.png
# formula_images_processed/6f8cc2ba9d.png
# formula_images_processed/28d9683d0c.png
# formula_images_processed/74d7f926ca.png
# formula_images_processed/47c6336c02.png
# formula_images_processed/7102d488af.png
# formula_images_processed/7d19d7e3b0.png
# formula_images_processed/5373dba37c.png
# formula_images_processed/7ce6bc5597.png
# formula_images_processed/4f393caffd.png
# formula_images_processed/27b68e2c88.png
# formula_images_processed/7d29a93bc8.png
# formula_images_processed/26747da53c.png
# formula_images_processed/6836e85253.png
# formula_images_processed/3ae5c0ea67.png
# formula_images_processed/6025982f1d.png
# formula_images_processed/69e5aef82b.png
# formula_images_processed/4e5206030f.png
# formula_images_processed/65f848c5ed.png
# formula_images_processed/2dc06d1737.png
# formula_images_processed/680c2d13c0.png
# formula_images_processed/1da17bc33a.png
# formula_images_processed/3bf708da5a.png
# formula_images_processed/3917c434be.png
# formula_images_processed/471d4175f7.png
# formula_images_processed/56a718cb24.png
# formula_images_processed/5a092b0b29.png
# formula_images_processed/27510e3b4b.png
# formula_images_processed/17ca139218.png
# formula_images_processed/3dd2a882f2.png
# formula_images_processed/1c2eae51cb.png
# formula_images_processed/7faaf58f96.png
# formula_images_processed/2e24252969.png
# formula_images_processed/76b306e07a.png
# formula_images_processed/441a806238.png
# formula_images_processed/759c1ecdc0.png
# formula_images_processed/64f93cb0ec.png
# formula_images_processed/753da2b877.png
# formula_images_processed/6928e57b41.png
# formula_images_processed/4427880d65.png
# formula_images_processed/360bcadeba.png
# formula_images_processed/346bdcc58c.png
# formula_images_processed/791ef334a9.png
# formula_images_processed/3cdfc76b28.png
# formula_images_processed/7ab2f458e0.png
# formula_images_processed/7005cd3054.png
# formula_images_processed/1ebd04f2e7.png
# formula_images_processed/516c343f65.png
# formula_images_processed/120af3894d.png
# formula_images_processed/1dd4be67fa.png
# formula_images_processed/2e3f4dba57.png
# formula_images_processed/2252bc520c.png
# formula_images_processed/32762c8db6.png
# formula_images_processed/215515664f.png
# formula_images_processed/66638ae935.png
# formula_images_processed/2e27d689b4.png
# formula_images_processed/10ec22c580.png
# formula_images_processed/f016898ef5.png
# formula_images_processed/1a27258688.png
# formula_images_processed/70faf0e0d7.png
# formula_images_processed/550ea68cc3.png
# formula_images_processed/55893ac841.png
# formula_images_processed/6c02c7c786.png
# formula_images_processed/5e4f9519a5.png
# formula_images_processed/4348b3dda2.png
# formula_images_processed/6fc8e4e7cc.png
# formula_images_processed/4c8e04ee2d.png
# formula_images_processed/6a5514cb5f.png
# formula_images_processed/7ba4431a07.png
# formula_images_processed/25b4364d58.png
# formula_images_processed/fd884d5bc2.png
# formula_images_processed/662c35c311.png
# formula_images_processed/ff15323d1a.png
# formula_images_processed/7f148a19eb.png
# formula_images_processed/4dc3f728e9.png
# formula_images_processed/541e45c81a.png
# formula_images_processed/11598d0347.png
# formula_images_processed/2115b8cd60.png
# formula_images_processed/3483fe668a.png
# formula_images_processed/7f5c0d092a.png
# formula_images_processed/1fab5cf962.png
# formula_images_processed/187590cf8c.png
# formula_images_processed/184477642e.png
# formula_images_processed/2e4aadca7b.png
# formula_images_processed/7030e93752.png
# formula_images_processed/17499a408d.png
# formula_images_processed/324436f38c.png
# formula_images_processed/530606c756.png
# formula_images_processed/68b5a631e2.png
# formula_images_processed/63df506977.png
# formula_images_processed/2565cffd62.png
# formula_images_processed/7ad0dbfe92.png
# formula_images_processed/21a523794f.png
# formula_images_processed/2592adc531.png
# formula_images_processed/cd65317428.png
# formula_images_processed/2d03c437ed.png
# formula_images_processed/6103a27b71.png
# formula_images_processed/2cff6b0ebf.png
# formula_images_processed/5127b28e21.png
# formula_images_processed/307f45c66b.png
# formula_images_processed/4a3a7816d3.png
# formula_images_processed/3a032d41ab.png
# formula_images_processed/6ca71faaef.png
# formula_images_processed/1407985052.png
# formula_images_processed/25df37c207.png
# formula_images_processed/250a06704d.png
# formula_images_processed/2a57b6e65b.png
# formula_images_processed/5601e6f98b.png
# formula_images_processed/70b3cfbfcb.png
# formula_images_processed/74e81da3aa.png
# formula_images_processed/70065e4d37.png
# formula_images_processed/44f888c164.png
# formula_images_processed/7e79a8408e.png
# formula_images_processed/594ba2a003.png
# formula_images_processed/5577e0135d.png
# formula_images_processed/1c13ea9fdb.png
# formula_images_processed/750a0987f8.png
# formula_images_processed/422af11137.png
# formula_images_processed/5661148898.png
# formula_images_processed/e75e5211ea.png
# formula_images_processed/5d9f7c68a3.png
# formula_images_processed/d3987062a6.png
# formula_images_processed/40750d3fc1.png
# formula_images_processed/472eb5c324.png
# formula_images_processed/5fb795a7de.png
# formula_images_processed/306126f245.png
# formula_images_processed/2d981c7f14.png
# formula_images_processed/6657e5bf8a.png
# formula_images_processed/291de190a2.png
# formula_images_processed/6dfed377c9.png
# formula_images_processed/15bd06cad2.png
# formula_images_processed/11b087bc3e.png
# formula_images_processed/62cf11f09e.png
# formula_images_processed/a9e0182860.png
# formula_images_processed/57a7936e2a.png
# formula_images_processed/1b41f9609c.png
# formula_images_processed/66f14e081a.png
# formula_images_processed/12f741e874.png
# formula_images_processed/102fb2ab21.png
# formula_images_processed/7fd5858149.png
# formula_images_processed/56f914140a.png
# formula_images_processed/26a665f671.png
# formula_images_processed/b510435d8d.png
# formula_images_processed/5b9847cd5d.png
# formula_images_processed/6c054b91af.png
# formula_images_processed/19a5b21714.png
# formula_images_processed/3454384801.png
# formula_images_processed/7783755086.png
# formula_images_processed/9fea8e6e71.png
# formula_images_processed/174be287d7.png
# formula_images_processed/67fd482313.png
# formula_images_processed/5b8ce73133.png
# formula_images_processed/1969d8dd66.png
# formula_images_processed/11589b7de4.png
# formula_images_processed/7b25e24df8.png
# formula_images_processed/4f6405a8ea.png
# formula_images_processed/1cf8aafc27.png
# formula_images_processed/6a4744afef.png
# formula_images_processed/68043bf137.png
# formula_images_processed/23a73dec64.png
# formula_images_processed/28f3bc5267.png
# formula_images_processed/33fcc137f2.png
# formula_images_processed/21e28fe5c8.png
# formula_images_processed/b42f4ec3bc.png
# formula_images_processed/6488a3c343.png
# formula_images_processed/52a82e6f6d.png
# formula_images_processed/22108e484e.png
# formula_images_processed/57f6eb559e.png
# formula_images_processed/392f33f99e.png
# formula_images_processed/101e1b2dbc.png
# formula_images_processed/4e9fc492f8.png
# formula_images_processed/48cfe4abcc.png
# formula_images_processed/6ba3b555bd.png
# formula_images_processed/53a09fa0d9.png
# formula_images_processed/eb9d0a0d03.png
# formula_images_processed/2238346340.png
# formula_images_processed/4d02a80952.png
# formula_images_processed/2e519f25ce.png
# formula_images_processed/b8496b14ed.png
# formula_images_processed/6a03882c49.png
# formula_images_processed/750091aaee.png
# formula_images_processed/43327e5d19.png
# formula_images_processed/5d347b6f78.png
# formula_images_processed/63bfc99ceb.png
# formula_images_processed/72e135dc47.png
# formula_images_processed/5d598d4ac0.png
# formula_images_processed/6d688de275.png
# formula_images_processed/10cba87442.png
# formula_images_processed/28efcf0cdb.png
# formula_images_processed/563599bdfd.png
# formula_images_processed/67b4aede3e.png
# formula_images_processed/4ac2bd29d7.png
# formula_images_processed/1bca4d4259.png
# formula_images_processed/5300fe5c41.png
# formula_images_processed/5b0d1be6f3.png
# formula_images_processed/43c9c143a7.png
# formula_images_processed/1a9c25bf23.png
# formula_images_processed/4a85f7057a.png
# formula_images_processed/5d949ae62a.png
# formula_images_processed/5613eac816.png
# formula_images_processed/63bb4ece9b.png
# formula_images_processed/73843705a4.png
# formula_images_processed/39917578cc.png
# formula_images_processed/57f1ec21d8.png
# formula_images_processed/441634a562.png
# formula_images_processed/4588a7d498.png
# formula_images_processed/75940ecd99.png
# formula_images_processed/126cb78990.png
# formula_images_processed/af4db845a9.png
# formula_images_processed/347afb94d5.png
# formula_images_processed/1afc02e916.png
# formula_images_processed/56b304364f.png
# formula_images_processed/651d607ef5.png
# formula_images_processed/77c71b148c.png
# formula_images_processed/77f74da857.png
# formula_images_processed/567a2dadcf.png
# formula_images_processed/2b7de5f06f.png
# formula_images_processed/69c0337295.png
# formula_images_processed/54b72191c6.png
# formula_images_processed/6564b50528.png
# formula_images_processed/2223cd5068.png
# formula_images_processed/6b5337f557.png
# formula_images_processed/2c2db9d077.png
# formula_images_processed/60c2c60c6a.png
# formula_images_processed/3a732f2369.png
# formula_images_processed/48dd5e5cbb.png
# formula_images_processed/4b190d2417.png
# formula_images_processed/34bd48ff8e.png
# formula_images_processed/3e40fe032a.png
# formula_images_processed/6b1f46d588.png
# formula_images_processed/64daea677f.png
# formula_images_processed/6b959d082c.png
# formula_images_processed/59499a7317.png
# formula_images_processed/50c9666ae9.png
# formula_images_processed/381593c99d.png
# formula_images_processed/1e683eb72f.png
# formula_images_processed/6f8fd8cf35.png
# formula_images_processed/5dff8edae3.png
# formula_images_processed/7722a1558f.png
# formula_images_processed/dbcfd3c9df.png
# formula_images_processed/4eaec850da.png
# formula_images_processed/16f75c1687.png
# formula_images_processed/623095e822.png
# formula_images_processed/250d254d99.png
# formula_images_processed/7f69dc9dcb.png
# formula_images_processed/386ec3fd10.png
# formula_images_processed/466ac047ee.png
# formula_images_processed/551f1f04c2.png
# formula_images_processed/545e112ffa.png
# formula_images_processed/41e02e1b49.png
# formula_images_processed/2b0830ad87.png
# formula_images_processed/29638fcdda.png
# formula_images_processed/73a6c12a14.png
# formula_images_processed/47c9fdd863.png
# formula_images_processed/4a6c37db60.png
# formula_images_processed/4c3d3cfe43.png
# formula_images_processed/77762d421d.png
# formula_images_processed/4e838ec90b.png
# formula_images_processed/23ce39eb1b.png
# formula_images_processed/5b246b6c24.png
# formula_images_processed/16dc37f447.png
# formula_images_processed/37fdd930d4.png
# formula_images_processed/669e09542d.png
# formula_images_processed/4da7621d40.png
# formula_images_processed/5dd516d6db.png
# formula_images_processed/6959ce370a.png
# formula_images_processed/5da96ce763.png
# formula_images_processed/79f7b16acd.png
# formula_images_processed/21ec53f529.png
# formula_images_processed/3b16a89841.png
# formula_images_processed/43d4f89d65.png
# formula_images_processed/1b41be9de5.png
# formula_images_processed/56979e8be2.png
# formula_images_processed/59e44459b1.png
# formula_images_processed/4536861b67.png
# formula_images_processed/68cac0060d.png
# formula_images_processed/6221cb8f55.png
# formula_images_processed/255ff68c17.png
# formula_images_processed/3b732f7085.png
# formula_images_processed/1491bc9ab0.png
# formula_images_processed/71194e9562.png
# formula_images_processed/54b420a3f4.png
# formula_images_processed/313f58b692.png
# formula_images_processed/29adafdffd.png
# formula_images_processed/5d51edeacf.png
# formula_images_processed/4ff79a1fef.png
# formula_images_processed/2dc179c316.png
# formula_images_processed/189d0be090.png
# formula_images_processed/4568b012a2.png
# formula_images_processed/657fe6277d.png
# formula_images_processed/67b71c65c5.png
# formula_images_processed/ec9e7cfd70.png
# formula_images_processed/300e5542f0.png
# formula_images_processed/718fef0565.png
# formula_images_processed/69ad8acc33.png
# formula_images_processed/3e8d2e7de9.png
# formula_images_processed/21a9781e31.png
# formula_images_processed/6d517a100b.png
# formula_images_processed/2cfceea7e5.png
# formula_images_processed/30102bafb4.png
# formula_images_processed/1581797885.png
# formula_images_processed/e69a319d31.png
# formula_images_processed/26364cfca8.png
# formula_images_processed/6de1875142.png
# formula_images_processed/5c01eebdea.png
# formula_images_processed/77b5178a55.png
# formula_images_processed/7fcd587863.png
# formula_images_processed/1f1a72e515.png
# formula_images_processed/54f3e96b73.png
# formula_images_processed/7e79de853b.png
# formula_images_processed/274107536f.png
# formula_images_processed/30fdcdd5a2.png
# formula_images_processed/3c3271f3d7.png
# formula_images_processed/18d14c5388.png
# formula_images_processed/600858549a.png
# formula_images_processed/7f9bbed2fb.png
# formula_images_processed/141769832c.png
# formula_images_processed/1352611538.png
# formula_images_processed/26f0000372.png
# formula_images_processed/3ca02fc0d4.png
# formula_images_processed/23a83fbd06.png
# formula_images_processed/2417762e34.png
# formula_images_processed/66125c58ce.png
# formula_images_processed/c876a1f63f.png
# formula_images_processed/53f588de45.png
# formula_images_processed/150dded56f.png
# formula_images_processed/3ede98897b.png
# formula_images_processed/f009869b01.png
# formula_images_processed/4c5aeab436.png
# formula_images_processed/3681ea0dee.png
# formula_images_processed/70452d3206.png
# formula_images_processed/4270860750.png
# formula_images_processed/6279bfd1a7.png
# formula_images_processed/4928a64d38.png
# formula_images_processed/56094fb9ce.png
# formula_images_processed/ead484cfdf.png
# formula_images_processed/60e6f9c407.png
# formula_images_processed/f2360e6ba8.png
# formula_images_processed/656afb0fae.png
# formula_images_processed/47fbdac0df.png
# formula_images_processed/2af3cc0923.png
# formula_images_processed/180d06c7af.png
# formula_images_processed/5f16f0b201.png
# formula_images_processed/48adf7d02e.png
# formula_images_processed/5c1b796c9f.png
# formula_images_processed/7464877f90.png
# formula_images_processed/77698e6a46.png
# formula_images_processed/5ae5bff0e5.png
# formula_images_processed/737049219a.png
# formula_images_processed/399f73bc73.png
# formula_images_processed/625f4f2489.png
# formula_images_processed/3fe0af48cd.png
# formula_images_processed/56ee7efdb2.png
# formula_images_processed/138d38a6e6.png
# formula_images_processed/60aeb776fe.png
# formula_images_processed/322bc285db.png
# formula_images_processed/672e513539.png
# formula_images_processed/2e8f47cb38.png
# formula_images_processed/22d0114ace.png
# formula_images_processed/6d83d56d24.png
# formula_images_processed/5bb368d2b7.png
# formula_images_processed/6b6487e170.png
# formula_images_processed/748c646530.png
# formula_images_processed/686b851984.png
# formula_images_processed/51ed9a9906.png
# formula_images_processed/6bfa38f54e.png
# formula_images_processed/222af9a578.png
# formula_images_processed/2ec09ca767.png
# formula_images_processed/5fdd9c51e3.png
# formula_images_processed/4073d5d965.png
# formula_images_processed/2a57607152.png
# formula_images_processed/2296827292.png
# formula_images_processed/1859ed4e6d.png
# formula_images_processed/447c3ce933.png
# formula_images_processed/4f363932ab.png
# formula_images_processed/748182ab41.png
# formula_images_processed/6c9a51304f.png
# formula_images_processed/272ab1fb0a.png
# formula_images_processed/77de451702.png
# formula_images_processed/366b643caa.png
# formula_images_processed/3453cec6d3.png
# formula_images_processed/1a4ef0635c.png
# formula_images_processed/88db137088.png
# formula_images_processed/2a7dc8fc47.png
# formula_images_processed/270cd2be7b.png
# formula_images_processed/3957497a48.png
# formula_images_processed/444a5a8bf4.png
# formula_images_processed/292a180dad.png
# formula_images_processed/33b13d8be3.png
# formula_images_processed/e156816416.png
# formula_images_processed/107cecb3a9.png
# formula_images_processed/1f9633d4d1.png
# formula_images_processed/19b55b3e87.png
# formula_images_processed/6bdaea7886.png
# formula_images_processed/36d3ccbe8d.png
# formula_images_processed/318433611f.png
# formula_images_processed/fab46c4752.png
# formula_images_processed/6af4191d54.png
# formula_images_processed/437ec9cfee.png
# formula_images_processed/4d1d2ace19.png
# formula_images_processed/1ed23dde13.png
# formula_images_processed/3be6751a8d.png
# formula_images_processed/3d4e30fc8c.png
# formula_images_processed/50a012ecd2.png
# formula_images_processed/7f4122e9b4.png
# formula_images_processed/28eb793ce2.png
# formula_images_processed/707922f644.png
# formula_images_processed/44f2f14b38.png
# formula_images_processed/1b66fd11d9.png
# formula_images_processed/3611fe4ed0.png
# formula_images_processed/37cea0c523.png
# formula_images_processed/4469041d94.png
# formula_images_processed/709b74b04f.png
# formula_images_processed/635871a904.png
# formula_images_processed/19778ed54a.png
# formula_images_processed/154b02e7ed.png
# formula_images_processed/4060f9d324.png
# formula_images_processed/66c18eeded.png
# formula_images_processed/2613d88661.png
# formula_images_processed/36f0d4c458.png
# formula_images_processed/77dee1ffb0.png
# formula_images_processed/7da11b3e2d.png
# formula_images_processed/11ab95c172.png
# formula_images_processed/3b93f3ae25.png
# formula_images_processed/6d0bfba626.png
# formula_images_processed/7dc41cdba6.png
# formula_images_processed/2eb38888a2.png
# formula_images_processed/2eac0a9805.png
# formula_images_processed/738762d1ab.png
# formula_images_processed/39afb79c62.png
# formula_images_processed/99e804c8da.png
# formula_images_processed/2fb6523526.png
# formula_images_processed/2f17460ee6.png
# formula_images_processed/ac6044adcf.png
# formula_images_processed/1250944176.png
# formula_images_processed/18862cd004.png
# formula_images_processed/38c6251fee.png
# formula_images_processed/6ec37907a7.png
# formula_images_processed/1662b05297.png
# formula_images_processed/345653ba41.png
# formula_images_processed/115dc9b4c3.png
# formula_images_processed/3d4163a450.png
# formula_images_processed/185f28b087.png
# formula_images_processed/7dc85da548.png
# formula_images_processed/696a097fe8.png
# formula_images_processed/b1c9bea51c.png
# formula_images_processed/3c159d6ae8.png
# formula_images_processed/2864fad916.png
# formula_images_processed/1147ba3802.png
# formula_images_processed/38702e7381.png
# formula_images_processed/7c9cfdd26d.png
# formula_images_processed/1c3a9daede.png
# formula_images_processed/3020981eb2.png
# formula_images_processed/1790dd5c56.png
# formula_images_processed/1a2363f00b.png
# formula_images_processed/54a619698b.png
# formula_images_processed/6e13a263e6.png
# formula_images_processed/408e4966e1.png
# formula_images_processed/6e9306a976.png
# formula_images_processed/3b97242aa1.png
# formula_images_processed/2e3fdd931a.png
# formula_images_processed/564dd1c319.png
# formula_images_processed/4e0f3c6012.png
# formula_images_processed/264953f1c6.png
# formula_images_processed/618414f83c.png
# formula_images_processed/7548a6e33c.png
# formula_images_processed/6aec6e4120.png
# formula_images_processed/49303c7877.png
# formula_images_processed/7b3d6a94de.png
# formula_images_processed/15edd2054f.png
# formula_images_processed/7049f2b4c6.png
# formula_images_processed/24751c5aca.png
# formula_images_processed/11c6250cbb.png
# formula_images_processed/4f9bf2ddef.png
# formula_images_processed/40074c062c.png
# formula_images_processed/174957cc33.png
# formula_images_processed/57c0486c87.png
# formula_images_processed/3781a2be4b.png
# formula_images_processed/37de6ec022.png
# formula_images_processed/1a7a91258a.png
# formula_images_processed/21e38d8c80.png
# formula_images_processed/4eea0e36f2.png
# formula_images_processed/418723daab.png
# formula_images_processed/20a4b7af45.png
# formula_images_processed/4655fe2c16.png
# formula_images_processed/45974136f2.png
# formula_images_processed/234ebe656e.png
# formula_images_processed/37503bf48d.png
# formula_images_processed/e8939630b2.png
# formula_images_processed/555113d209.png
# formula_images_processed/363734b989.png
# formula_images_processed/39e0ac30cc.png
# formula_images_processed/75cc81c395.png
# formula_images_processed/21c9fecce3.png
# formula_images_processed/56586a446f.png
# formula_images_processed/3c523ff5eb.png
# formula_images_processed/5ffa42e54a.png
# formula_images_processed/1f10cee12b.png
# formula_images_processed/40f7437079.png
# formula_images_processed/765c464d01.png
# formula_images_processed/2c3bd2f8a3.png
# formula_images_processed/292581af88.png
# formula_images_processed/6570f70c9d.png
# formula_images_processed/76c1bb3bb0.png
# formula_images_processed/6a445e384f.png
# formula_images_processed/647cc2ec7c.png
# formula_images_processed/6b51e0d1ab.png
# formula_images_processed/358c403157.png
# formula_images_processed/742ec92db0.png
# formula_images_processed/2ff53106dd.png
# formula_images_processed/8a869f6efe.png
# formula_images_processed/729154801f.png
# formula_images_processed/43e24e4c88.png
# formula_images_processed/688798aeb7.png
# formula_images_processed/23cac52be5.png
# formula_images_processed/55bc77521a.png
# formula_images_processed/537e94ffdd.png
# formula_images_processed/17b9690f42.png
# formula_images_processed/68619f822a.png
# formula_images_processed/357a6f2549.png
# formula_images_processed/982a3158be.png
# formula_images_processed/46a35bf87c.png
# formula_images_processed/512e355507.png
# formula_images_processed/a753aec99c.png
# formula_images_processed/477fe37ad2.png
# formula_images_processed/34481954c1.png
# formula_images_processed/32d715bbd4.png
# formula_images_processed/5959004c24.png
# formula_images_processed/2d33ea3bc7.png
# formula_images_processed/1fc157c17d.png
# formula_images_processed/78027d9440.png
# formula_images_processed/7ef0f5d1d6.png
# formula_images_processed/41b911d665.png
# formula_images_processed/6189fbe7e5.png
# formula_images_processed/bd0507f41c.png
# formula_images_processed/39cb4f5c47.png
# formula_images_processed/391993eab9.png
# formula_images_processed/7684d6f9d6.png
# formula_images_processed/11322a6d22.png
# formula_images_processed/4f9e356428.png
# formula_images_processed/3890fcf19c.png
# formula_images_processed/79c248c415.png
# formula_images_processed/3342c560e9.png
# formula_images_processed/be20051a87.png
# formula_images_processed/56f48f30eb.png
# formula_images_processed/299413bdc8.png
# formula_images_processed/3f74fd1831.png
# formula_images_processed/498f5f8a51.png
# formula_images_processed/38ec124d31.png
# formula_images_processed/260e6647be.png
# formula_images_processed/5db597d4d7.png
# formula_images_processed/6c7b7e67b0.png
# formula_images_processed/5542629bc6.png
# formula_images_processed/3a40a4e7a5.png
# formula_images_processed/652e65e8fe.png
# formula_images_processed/58c16cac4c.png
# formula_images_processed/34f82861fb.png
# formula_images_processed/e889e88112.png
# formula_images_processed/4943d89a24.png
# formula_images_processed/6302a92766.png
# formula_images_processed/50a89bdc56.png
# formula_images_processed/6cf8998fad.png
# formula_images_processed/34aebe666d.png
# formula_images_processed/55d0d5d273.png
# formula_images_processed/75cee100bc.png
# formula_images_processed/353906a519.png
# formula_images_processed/5432969304.png
# formula_images_processed/11cd0024dc.png
# formula_images_processed/f8481247fe.png
# formula_images_processed/4e922201a7.png
# formula_images_processed/8560e9bb8e.png
# formula_images_processed/a9a1113213.png
# formula_images_processed/57dbae7451.png
# formula_images_processed/698bd39f79.png
# formula_images_processed/73f53aa1d8.png
# formula_images_processed/5724333aa7.png
# formula_images_processed/27f269d957.png
# formula_images_processed/1e3467672b.png
# formula_images_processed/3cc75a93f1.png
# formula_images_processed/16abf3bea8.png
# formula_images_processed/46ca7ebb35.png
# formula_images_processed/301662e8cc.png
# formula_images_processed/4185da7220.png
# formula_images_processed/41b56dee39.png
# formula_images_processed/3d77518179.png
# formula_images_processed/78149304c6.png
# formula_images_processed/626fb352a9.png
# formula_images_processed/54fd342cd7.png
# formula_images_processed/5f14ff84d1.png
# formula_images_processed/55db4bccba.png
# formula_images_processed/690dffbaf6.png
# formula_images_processed/74c7528c4a.png
# formula_images_processed/4cf10930cf.png
# formula_images_processed/44cd3ed53a.png
# formula_images_processed/18ea999056.png
# formula_images_processed/6c1f809c11.png
# formula_images_processed/2fb8b57f48.png
# formula_images_processed/33d879d8c5.png
# formula_images_processed/728b25904a.png
# formula_images_processed/6968dfca15.png
# formula_images_processed/62dbeda37a.png
# formula_images_processed/7250fe1440.png
# formula_images_processed/2540b6d95a.png
# formula_images_processed/2733b66522.png
# formula_images_processed/5a57ddb47b.png
# formula_images_processed/7ab1ab4fec.png
# formula_images_processed/c505bded66.png
# formula_images_processed/4496477513.png
# formula_images_processed/39c840849c.png
# formula_images_processed/572dfe18b7.png
# formula_images_processed/3e60c54976.png
# formula_images_processed/292325745f.png
# formula_images_processed/84185a1001.png
# formula_images_processed/61b3bdc250.png
# formula_images_processed/32ec420ce7.png
# formula_images_processed/5123dc3f0f.png
# formula_images_processed/28ed57b6d6.png
# formula_images_processed/62e353a95f.png
# formula_images_processed/6905c7123d.png
# formula_images_processed/4ae6075e3a.png
# formula_images_processed/50dae1865f.png
# formula_images_processed/4237a4a427.png
# formula_images_processed/27674a5f02.png
# formula_images_processed/2f21b2aeb3.png
# formula_images_processed/6f6a78560b.png
# formula_images_processed/eef09b363e.png
# formula_images_processed/6029ade37e.png
# formula_images_processed/525b0bf89a.png
# formula_images_processed/386da3ad50.png
# formula_images_processed/7c2728305e.png
# formula_images_processed/3c8bff4b6f.png
# formula_images_processed/2a8e59c52a.png
# formula_images_processed/2556d15e90.png
# formula_images_processed/10ae160ac0.png
# formula_images_processed/6d6c08ca3a.png
# formula_images_processed/2e9bf44b74.png
# formula_images_processed/34f7449467.png
# formula_images_processed/4689d6fbb3.png
# formula_images_processed/7f9018fc4a.png
# formula_images_processed/30777b3aa6.png
# formula_images_processed/456cf2a15e.png
# formula_images_processed/480cac4814.png
# formula_images_processed/7104483611.png
# formula_images_processed/6f84cd485e.png
# formula_images_processed/52b067df64.png
# formula_images_processed/2c49c835b9.png
# formula_images_processed/39cbf58c93.png
# formula_images_processed/736ff12d92.png
# formula_images_processed/160dabb012.png
# formula_images_processed/403bb5e53a.png
# formula_images_processed/4d657ac5cb.png
# formula_images_processed/4d119103c5.png
# formula_images_processed/5cddd3717c.png
# formula_images_processed/69cfd297c6.png
# formula_images_processed/179109ef54.png
# formula_images_processed/2ab402b19d.png
# formula_images_processed/136887ce07.png
# formula_images_processed/23e69faf37.png
# formula_images_processed/6c1aeeaf5a.png
# formula_images_processed/6cb3ba57ae.png
# formula_images_processed/28265f7ed8.png
# formula_images_processed/526ea75c7e.png
# formula_images_processed/5e7bcf3429.png
# formula_images_processed/40838ebe23.png
# formula_images_processed/39612e5b7b.png
# formula_images_processed/337b06db63.png
# formula_images_processed/4b24fa86af.png
# formula_images_processed/7e59eb2f1e.png
# formula_images_processed/5b319678b3.png
# formula_images_processed/1e39d3c504.png
# formula_images_processed/594d99159c.png
# formula_images_processed/55bc26c397.png
# formula_images_processed/6f117e5658.png
# formula_images_processed/5b85d9253b.png
# formula_images_processed/e5f8dd665c.png
# formula_images_processed/3afd1d5116.png
# formula_images_processed/2419a38f12.png
# formula_images_processed/a34dc7a4fe.png
# formula_images_processed/26db4aec1e.png
# formula_images_processed/14c9fd001f.png
# formula_images_processed/77b449c980.png
# formula_images_processed/27449bc5ff.png
# formula_images_processed/211be668ec.png
# formula_images_processed/6468c6778a.png
# formula_images_processed/5ab7b07f52.png
# formula_images_processed/29d7e30511.png
# formula_images_processed/6ef532595c.png
# formula_images_processed/694a824942.png
# formula_images_processed/e9348b7889.png
# formula_images_processed/472781b5c8.png
# formula_images_processed/3030ec8cb7.png
# formula_images_processed/1cd447d69f.png
# formula_images_processed/efe69bdb6e.png
# formula_images_processed/469a44b5be.png
# formula_images_processed/5ed9b9dd19.png
# formula_images_processed/55b9cce1eb.png
# formula_images_processed/19a8e5fba1.png
# formula_images_processed/1cfe04dafa.png
# formula_images_processed/6fb2868dbc.png
# formula_images_processed/d2652eb1f0.png
# formula_images_processed/5d8b460df6.png
# formula_images_processed/698af7e63e.png
# formula_images_processed/3db903578b.png
# formula_images_processed/256f1e5b2a.png
# formula_images_processed/4e83ea6b03.png
# formula_images_processed/3a74846139.png
# formula_images_processed/6f70257c1e.png
# formula_images_processed/72982a5d6f.png
# formula_images_processed/69bfb499c7.png
# formula_images_processed/329839ebe0.png
# formula_images_processed/3e6fac7657.png
# formula_images_processed/54a44bbe7c.png
# formula_images_processed/71a218d878.png
# formula_images_processed/53577af163.png
# formula_images_processed/622e92ca35.png
# formula_images_processed/7d431996cd.png
# formula_images_processed/5d7078160a.png
# formula_images_processed/4631ece2ca.png
# formula_images_processed/1c7f5a7d56.png
# formula_images_processed/7c7f22d841.png
# formula_images_processed/634a8ef735.png
# formula_images_processed/3170539d38.png
# formula_images_processed/2b1e0c3884.png
# formula_images_processed/de1c91f527.png
# formula_images_processed/3ec162e29e.png
# formula_images_processed/5c64fe6ce5.png
# formula_images_processed/73aec76b24.png
# formula_images_processed/69d4f5f2aa.png
# formula_images_processed/31a3c39a62.png
# formula_images_processed/4cdc84c91e.png
# formula_images_processed/29c135b472.png
# formula_images_processed/2b585e35db.png
# formula_images_processed/3cbe205f66.png
# formula_images_processed/24b2013415.png
# formula_images_processed/d9c84cebe6.png
# formula_images_processed/264dea3de4.png
# formula_images_processed/5ac3c901f6.png
# formula_images_processed/58f75bb39f.png
# formula_images_processed/37649ca4d3.png
# formula_images_processed/294e67667b.png
# formula_images_processed/79dbc83ef5.png
# formula_images_processed/59d9ea04f0.png
# formula_images_processed/9b70f72381.png
# formula_images_processed/63360cd751.png
# formula_images_processed/32c665f1f1.png
# formula_images_processed/6df783de24.png
# formula_images_processed/1baba03963.png
# formula_images_processed/382a42e4d9.png
# formula_images_processed/5cd65759f9.png
# formula_images_processed/6936e83f53.png
# formula_images_processed/570e9efdaf.png
# formula_images_processed/3a951340b0.png
# formula_images_processed/27738979da.png
# formula_images_processed/78dcbe49c1.png
# formula_images_processed/64da3806bc.png
# formula_images_processed/27bdd7bb48.png
# formula_images_processed/759b4b79c0.png
# formula_images_processed/678b725993.png
# formula_images_processed/6aa645d8df.png
# formula_images_processed/15e05442f6.png
# formula_images_processed/3207b6ffeb.png
# formula_images_processed/eb86912230.png
# formula_images_processed/2705c009a6.png
# formula_images_processed/7a84b09b84.png
# formula_images_processed/559e0d97ff.png
# formula_images_processed/72a004916d.png
# formula_images_processed/48ab8ab69b.png
# formula_images_processed/3b74771873.png
# formula_images_processed/6f95dcb90a.png
# formula_images_processed/3ce13539a1.png
# formula_images_processed/2ea9c2f4f9.png
# formula_images_processed/34baadcfb5.png
# formula_images_processed/22c44024c6.png
# formula_images_processed/7741323eaf.png
# formula_images_processed/2a4fcd7988.png
# formula_images_processed/97a6226ad7.png
# formula_images_processed/320c32e629.png
# formula_images_processed/fd0ab4d060.png
# formula_images_processed/4b744439fb.png
# formula_images_processed/2b447fcfed.png
# formula_images_processed/27dd47e8da.png
# formula_images_processed/fad2513e49.png
# formula_images_processed/1fb8527588.png
# formula_images_processed/6b3536061a.png
# formula_images_processed/5394993141.png
# formula_images_processed/3592f971b8.png
# formula_images_processed/40f217983b.png
# formula_images_processed/338be25970.png
# formula_images_processed/4a1911519d.png
# formula_images_processed/62d92147ab.png
# formula_images_processed/496f0354e4.png
# formula_images_processed/19d9c74a8d.png
# formula_images_processed/68844fd309.png
# formula_images_processed/4eb2ca1527.png
# formula_images_processed/4a8811c0c7.png
# formula_images_processed/f217347392.png
# formula_images_processed/5d065b6851.png
# formula_images_processed/450a09ae9a.png
# formula_images_processed/75e8452966.png
# formula_images_processed/25cbe0ed8e.png
# formula_images_processed/53f3782d48.png
# formula_images_processed/3e71e8c3e3.png
# formula_images_processed/5fbf0d8836.png
# formula_images_processed/75f060a09c.png
# formula_images_processed/4b353a5ff8.png
# formula_images_processed/56ebef4b0e.png
# formula_images_processed/d7b12c6cef.png
# formula_images_processed/415ce49704.png
# formula_images_processed/6f52a302c6.png
# formula_images_processed/2cef7d1256.png
# formula_images_processed/10af5faff5.png
# formula_images_processed/746e6abd33.png
# formula_images_processed/75a0438274.png
# formula_images_processed/2e7939f3c1.png
# formula_images_processed/36c6252233.png
# ...
# formula_images_processed/94d0326b1c.png
# formula_images_processed/4f112f60ba.png
# formula_images_processed/32737355cc.png
# formula_images_processed/65344fa209.png
# formula_images_processed/42ab97240d.png
# formula_images_processed/1828ac9223.png
# formula_images_processed/433ad275da.png
# formula_images_processed/11e59fdb73.png
# formula_images_processed/45730cf39d.png
# formula_images_processed/53d004d862.png
# formula_images_processed/319e0aa3c1.png
# formula_images_processed/9d9b1be6bd.png
# formula_images_processed/560f5cf44e.png
# formula_images_processed/6410b505c9.png
# formula_images_processed/7ea030129c.png
# formula_images_processed/69f7581bb2.png
# formula_images_processed/4292fc5340.png
# formula_images_processed/702f1a00f8.png
# formula_images_processed/1dfb08e22c.png
# formula_images_processed/729c52f382.png
# formula_images_processed/255b5c8178.png
# formula_images_processed/52992b49fe.png
# formula_images_processed/c035b96809.png
# formula_images_processed/7a67dd0ba1.png
# formula_images_processed/38e0cfc0fa.png
# formula_images_processed/78446e4f3c.png
# formula_images_processed/1e2ebcc86c.png
# formula_images_processed/5d79d819d4.png
# formula_images_processed/48411c82c8.png
# formula_images_processed/7dbeeb6d97.png
# formula_images_processed/1072c2da25.png
# formula_images_processed/3773c6b147.png
# formula_images_processed/36ddab8ebb.png
# formula_images_processed/2ab99f052c.png
# formula_images_processed/183455c725.png
# formula_images_processed/2222c75a46.png
# formula_images_processed/3a70dce6ec.png
# formula_images_processed/40c804e4d8.png
# formula_images_processed/34b22d7ae1.png
# formula_images_processed/51fbdac3f3.png
# formula_images_processed/70d6278040.png
# formula_images_processed/5fc037eaa2.png
# formula_images_processed/7ee4b062dd.png
# formula_images_processed/43c7270349.png
# formula_images_processed/2294d17ac0.png
# formula_images_processed/3be563db24.png
# formula_images_processed/700d8cbd1b.png
# formula_images_processed/5870b555e3.png
# formula_images_processed/95a1cabb6d.png
# formula_images_processed/71a21c693d.png
# formula_images_processed/64616fa8fe.png
# formula_images_processed/6cc05aa255.png
# formula_images_processed/6fce0f0b0d.png
# formula_images_processed/6ec564c22d.png
# formula_images_processed/43675a0f7a.png
# formula_images_processed/ad81d3b8d0.png
# formula_images_processed/ef287c2c4e.png
# formula_images_processed/3d270fce35.png
# formula_images_processed/4d4afe88e7.png
# formula_images_processed/6f948b1ee1.png
# formula_images_processed/733ed8f99e.png
# formula_images_processed/4ebc5c4a10.png
# formula_images_processed/178c0ece6d.png
# formula_images_processed/6962fcb441.png
# formula_images_processed/62f8fa26e6.png
# formula_images_processed/57c6cf274d.png
# formula_images_processed/da20646901.png
# formula_images_processed/3a8c0abaac.png
# formula_images_processed/72846f7abe.png
# formula_images_processed/151eab6d58.png
# formula_images_processed/28b5175927.png
# formula_images_processed/6e1a10d2d3.png
# formula_images_processed/3d4edb2ca7.png
# formula_images_processed/1d456c797c.png
# formula_images_processed/749d274fa6.png
# formula_images_processed/4f9853bb8b.png
# formula_images_processed/63ce097cde.png
# formula_images_processed/51fa551acc.png
# formula_images_processed/85dd81ffd3.png
# formula_images_processed/42557b977f.png
# formula_images_processed/54943d647f.png
# formula_images_processed/2eb7d56080.png
# formula_images_processed/69b0e22bec.png
# formula_images_processed/4b8d32d820.png
# formula_images_processed/6f7c830422.png
# formula_images_processed/3b29e87d80.png
# formula_images_processed/6c34adea5f.png
# formula_images_processed/ccb5332dcf.png
# formula_images_processed/1afb272122.png
# formula_images_processed/25a9db5f96.png
# formula_images_processed/531fc36e2e.png
# formula_images_processed/7907041cd6.png
# formula_images_processed/451fd2d143.png
# formula_images_processed/584b95a222.png
# formula_images_processed/20f962a868.png
# formula_images_processed/8ea5f3fb7a.png
# formula_images_processed/782130c3cb.png
# formula_images_processed/ec80c63b31.png
# formula_images_processed/6b3cf3efc4.png
# formula_images_processed/4de10279dd.png
# formula_images_processed/52ee5b4292.png
# formula_images_processed/68a7b52be8.png
# formula_images_processed/399b00f7af.png
# formula_images_processed/5908670351.png
# formula_images_processed/aa5a838e18.png
# formula_images_processed/6b260dff38.png
# formula_images_processed/5cb842fdc6.png
# formula_images_processed/656905177b.png
# formula_images_processed/7933f23500.png
# formula_images_processed/5723b6be7e.png
# formula_images_processed/64faa3e501.png
# formula_images_processed/30fc47ef80.png
# formula_images_processed/39ca28022d.png
# formula_images_processed/5f547107cd.png
# formula_images_processed/1e18fa3774.png
# formula_images_processed/3a7352a84f.png
# formula_images_processed/681ea87786.png
# formula_images_processed/4776f1b0c8.png
# formula_images_processed/3222199186.png
# formula_images_processed/3ab50d0025.png
# formula_images_processed/db17fb95e5.png
# formula_images_processed/5056307daf.png
# formula_images_processed/330f73bcc1.png
# formula_images_processed/6544568ffc.png
# formula_images_processed/106beb8034.png
# formula_images_processed/1c319cb9fc.png
# formula_images_processed/38916b9e09.png
# formula_images_processed/36fc561a9b.png
# formula_images_processed/44dc2326d2.png
# formula_images_processed/4474515d24.png
# formula_images_processed/28ce3a2521.png
# formula_images_processed/3a9c50ae9e.png
# formula_images_processed/36aac14ca3.png
# formula_images_processed/7699cf6810.png
# formula_images_processed/206f4ad01c.png
# formula_images_processed/537c6f1eba.png
# formula_images_processed/6fbe4d1ffb.png
# formula_images_processed/161e563234.png
# formula_images_processed/2c6cdc6db9.png
# formula_images_processed/3055d37552.png
# formula_images_processed/4756ed2761.png
# formula_images_processed/36107d503b.png
# formula_images_processed/7d0e3ea49a.png
# formula_images_processed/e880bdc1c1.png
# formula_images_processed/3f55e48e59.png
# formula_images_processed/420f33c69a.png
# formula_images_processed/338c0472fe.png
# formula_images_processed/6192ed7aca.png
# formula_images_processed/16c650a09a.png
# formula_images_processed/3e43f072bc.png
# formula_images_processed/71075b78c8.png
# formula_images_processed/6edcc10261.png
# formula_images_processed/16d49f3c16.png
# formula_images_processed/5d47b4723c.png
# formula_images_processed/ef558c238d.png
# formula_images_processed/5c697e3726.png
# formula_images_processed/73e157ff08.png
# formula_images_processed/34f47a0bc6.png
# formula_images_processed/3a9ceae9f8.png
# formula_images_processed/2172eef0d1.png
# formula_images_processed/74465629ad.png
# formula_images_processed/42d7f12765.png
# formula_images_processed/150ee5588c.png
# formula_images_processed/3e5161f757.png
# formula_images_processed/1378cb7a3e.png
# formula_images_processed/15b4eae712.png
# formula_images_processed/cd45ca638f.png
# formula_images_processed/4ceeb24068.png
# formula_images_processed/4efaa35976.png
# formula_images_processed/16a44d470c.png
# formula_images_processed/74b535f207.png
# formula_images_processed/39a353e108.png
# formula_images_processed/2faa60b46e.png
# formula_images_processed/185f8d797e.png
# formula_images_processed/77229dfa9a.png
# formula_images_processed/251bf22533.png
# formula_images_processed/4b03d8fe38.png
# formula_images_processed/73d85f5eac.png
# formula_images_processed/1739eca16a.png
# formula_images_processed/49d5989f6b.png
# formula_images_processed/288019c5dd.png
# formula_images_processed/e3183c9884.png
# formula_images_processed/1e95001d53.png
# formula_images_processed/3d198756d6.png
# formula_images_processed/717f05835b.png
# formula_images_processed/4633234a27.png
# formula_images_processed/2c6bccecb3.png
# formula_images_processed/16800dcdad.png
# formula_images_processed/20b6b64d98.png
# formula_images_processed/72b8a33d20.png
# formula_images_processed/39da6e0e68.png
# formula_images_processed/2bd92c933c.png
# formula_images_processed/7d406bebf1.png
# formula_images_processed/5dbbed87ab.png
# formula_images_processed/6fd2a4d949.png
# formula_images_processed/5fc065f07b.png
# formula_images_processed/5e2657755b.png
# formula_images_processed/7f7fac8ba2.png
# formula_images_processed/1e5565443f.png
# formula_images_processed/795399ec4d.png
# formula_images_processed/446e72d69f.png
# formula_images_processed/3280bff224.png
# formula_images_processed/96b751bf19.png
# formula_images_processed/2efeaa0af7.png
# formula_images_processed/548b839593.png
# formula_images_processed/3e26d8f13d.png
# formula_images_processed/1f063b37fb.png
# formula_images_processed/490579c383.png
# formula_images_processed/16e9320ef7.png
# formula_images_processed/7e8dffea60.png
# formula_images_processed/286ad6194f.png
# formula_images_processed/8adfa46d9e.png
# formula_images_processed/767588ac25.png
# formula_images_processed/485b60cfc5.png
# formula_images_processed/6242d63005.png
# formula_images_processed/4102c68bb6.png
# formula_images_processed/51c1e11cbf.png
# formula_images_processed/3de8c1f7b0.png
# formula_images_processed/3ce4b3c92e.png
# formula_images_processed/48ae169d1d.png
# formula_images_processed/d7015148bd.png
# formula_images_processed/6f2d6fe9f6.png
# formula_images_processed/5001471bdc.png
# formula_images_processed/4af6ff1299.png
# formula_images_processed/b98a473351.png
# formula_images_processed/1cafe72cec.png
# formula_images_processed/28ec92a32f.png
# formula_images_processed/3805c7957e.png
# formula_images_processed/adb0476eef.png
# formula_images_processed/7de1f56090.png
# formula_images_processed/697f97cbff.png
# formula_images_processed/3f6f72c05e.png
# formula_images_processed/73f1699692.png
# formula_images_processed/94399cc743.png
# formula_images_processed/7fa95c647f.png
# formula_images_processed/22bf212812.png
# formula_images_processed/5320472213.png
# formula_images_processed/7e7193b6c1.png
# formula_images_processed/7d6a9b33d5.png
# formula_images_processed/4c65427060.png
# formula_images_processed/375af0ccce.png
# formula_images_processed/5aeddaf2c5.png
# formula_images_processed/42747d75c6.png
# formula_images_processed/7539e5b2cb.png
# formula_images_processed/24c46dcfaa.png
# formula_images_processed/12cb369ac1.png
# formula_images_processed/6fb19a1c95.png
# formula_images_processed/3a99395e77.png
# formula_images_processed/5e94af06f9.png
# formula_images_processed/1534e01c22.png
# formula_images_processed/37cb570990.png
# formula_images_processed/7d759782bc.png
# formula_images_processed/701e867998.png
# formula_images_processed/4646554f36.png
# formula_images_processed/1fdfb42eed.png
# formula_images_processed/3b1625c390.png
# formula_images_processed/8cea799b52.png
# formula_images_processed/662c58a822.png
# formula_images_processed/24753c31d7.png
# formula_images_processed/53efd6fcee.png
# formula_images_processed/1ed99595a0.png
# formula_images_processed/48c5aae560.png
# formula_images_processed/6150e4ef62.png
# formula_images_processed/2a444657d8.png
# formula_images_processed/49be7ec162.png
# formula_images_processed/30ac51ab9d.png
# formula_images_processed/31c69131f8.png
# formula_images_processed/2437399b32.png
# formula_images_processed/11c5eccd2f.png
# formula_images_processed/291e958264.png
# formula_images_processed/64a047fc92.png
# formula_images_processed/6d71116f1e.png
# formula_images_processed/2c78703564.png
# formula_images_processed/7504413dfe.png
# formula_images_processed/673887d293.png
# formula_images_processed/2556ecb351.png
# formula_images_processed/87f3b96fde.png
# formula_images_processed/33d0755e99.png
# formula_images_processed/4351602a1b.png
# formula_images_processed/11233f1473.png
# formula_images_processed/1f8a54d2ff.png
# formula_images_processed/2715a84d32.png
# formula_images_processed/3003fda028.png
# formula_images_processed/53eb8abc6a.png
# formula_images_processed/76a861c83f.png
# formula_images_processed/41a15e85e9.png
# formula_images_processed/5c84e045df.png
# formula_images_processed/37692df2f1.png
# formula_images_processed/61ba81b08d.png
# formula_images_processed/11c8250c34.png
# formula_images_processed/63cac23bf1.png
# formula_images_processed/5eea096399.png
# formula_images_processed/1acf3ff99c.png
# formula_images_processed/2358e6b04e.png
# formula_images_processed/404a6ebb86.png
# formula_images_processed/ebc46e1a08.png
# formula_images_processed/e7e9c75c85.png
# formula_images_processed/7f67194af5.png
# formula_images_processed/8013336ff3.png
# formula_images_processed/6b2c2ec1ba.png
# formula_images_processed/75a2e53ba7.png
# formula_images_processed/6887b2523d.png
# formula_images_processed/60afc5f266.png
# formula_images_processed/391371e38a.png
# formula_images_processed/2421f43bf1.png
# formula_images_processed/1d2f7233eb.png
# formula_images_processed/693b42d7b9.png
# formula_images_processed/69ddbad801.png
# formula_images_processed/3abcd50a25.png
# formula_images_processed/49a4f263bb.png
# formula_images_processed/3e8520dd61.png
# formula_images_processed/18a2281660.png
# formula_images_processed/723595ef48.png
# formula_images_processed/5fe80c07bb.png
# formula_images_processed/16375d5c5e.png
# formula_images_processed/5dfcfb34c8.png
# formula_images_processed/3c0c79ea81.png
# formula_images_processed/679f31c58b.png
# formula_images_processed/399be0458a.png
# formula_images_processed/1ccf195f90.png
# formula_images_processed/14acba90fa.png
# formula_images_processed/4927aada90.png
# formula_images_processed/14b6648705.png
# formula_images_processed/59fa4dc088.png
# formula_images_processed/92c3dd8778.png
# formula_images_processed/78bc3ad258.png
# formula_images_processed/428d59e59e.png
# formula_images_processed/35d33d18dd.png
# formula_images_processed/236ae91d6a.png
# formula_images_processed/602e8d6e6a.png
# formula_images_processed/2394c05b92.png
# formula_images_processed/3d738f9f12.png
# formula_images_processed/4fb91ccce8.png
# formula_images_processed/6875030242.png
# formula_images_processed/23a6e0a071.png
# formula_images_processed/12f78026d4.png
# formula_images_processed/af88514402.png
# formula_images_processed/548dfdcd63.png
# formula_images_processed/5279babdc8.png
# formula_images_processed/768f90d8e9.png
# formula_images_processed/31ba1435dd.png
# formula_images_processed/76209390b4.png
# formula_images_processed/7d1b3ffbd7.png
# formula_images_processed/495bc641ea.png
# formula_images_processed/14ed46c3af.png
# formula_images_processed/702cdbd8c2.png
# formula_images_processed/42519acc67.png
# formula_images_processed/a92732fd6f.png
# formula_images_processed/5dd8ec4a2a.png
# formula_images_processed/724a7ee85e.png
# formula_images_processed/4c559eae7f.png
# formula_images_processed/4d2b5ae63e.png
# formula_images_processed/73e3eecfe4.png
# formula_images_processed/2ae4a28c2f.png
# formula_images_processed/7f0430c5f9.png
# formula_images_processed/3b247f2304.png
# formula_images_processed/5a337dcb7b.png
# formula_images_processed/1914637a0b.png
# formula_images_processed/1ac88c07b8.png
# formula_images_processed/7f958e1e34.png
# formula_images_processed/2d6870b132.png
# formula_images_processed/50b353ef8a.png
# formula_images_processed/5bc3018d0f.png
# formula_images_processed/6ca3dad7f8.png
# formula_images_processed/3ab209ac02.png
# formula_images_processed/7879d60e5e.png
# formula_images_processed/2facffc848.png
# formula_images_processed/d06664a4d2.png
# formula_images_processed/44d735785b.png
# formula_images_processed/2ce455077b.png
# formula_images_processed/69f6763e5d.png
# formula_images_processed/722e2bd24e.png
# formula_images_processed/71fcf6510b.png
# formula_images_processed/6c5da0fe13.png
# formula_images_processed/630193fce7.png
# formula_images_processed/552a6010ba.png
# formula_images_processed/469236d531.png
# formula_images_processed/3e72285e7e.png
# formula_images_processed/2f8a30fa29.png
# formula_images_processed/2adb3731ad.png
# formula_images_processed/2e75cd5ea9.png
# formula_images_processed/38417d3163.png
# formula_images_processed/3eafc286fd.png
# formula_images_processed/2c963ec7d5.png
# formula_images_processed/379d1a1eb0.png
# formula_images_processed/2079ffb05b.png
# formula_images_processed/347a4fc717.png
# formula_images_processed/49debee6d7.png
# formula_images_processed/1150ecc5ad.png
# formula_images_processed/1046f834be.png
# formula_images_processed/3b57e95e9b.png
# formula_images_processed/78fc36e54c.png
# formula_images_processed/2733f0a98f.png
# formula_images_processed/64f5b9c07d.png
# formula_images_processed/35da8a54e8.png
# formula_images_processed/2011332225.png
# formula_images_processed/118b52b8b9.png
# formula_images_processed/781974528a.png
# formula_images_processed/3fad375208.png
# /content

# %%
DATA_DIR = "/content/dataset"

# %% [markdown]
# # Get the Vocablary
#
# We will record the frequency of each symbol and only store the symbol in the vocablary if it has minimum amount of frequency (certain threshold is reached)

# %%
vocab = dict()

SOS_TOKEN = '<SOS>'
EOS_TOKEN = '<EOS>'
PAD_TOKEN = '<PAD>'
UNK_TOKEN = '<UNK>'

vocab[PAD_TOKEN] = 0
vocab[SOS_TOKEN] = 1
vocab[EOS_TOKEN] = 2
vocab[UNK_TOKEN] = 3

length = 4
threshold = 5

frequency = dict()

def get_vocab(path, vocab, length):

  with open(f"{DATA_DIR}/im2latex_formulas.norm.lst", 'r') as f:
    formulas = f.read().strip('\n').split("\n")

  data = list()

  with open (f"{DATA_DIR}/{path}") as t:
    temp_list = t.read().split("\n")
    for each_info in temp_list:
      try:  
        img_name, idx = each_info.split(" ")
      except:
        print(f"Skipped : {each_info}")
        continue

      respective_formula = formulas[int(idx)]
      for each_sym in respective_formula.split():
        if each_sym in frequency:
          frequency[each_sym] += 1
        else:
          frequency[each_sym] = 1

        if frequency[each_sym] == threshold:
          vocab[each_sym] = length
          length += 1

      data.append([img_name, respective_formula])
  return data, vocab, length

train_data, vocab, length = get_vocab("im2latex_train_filter.lst", vocab, length)
valid_data, vocab, length = get_vocab("im2latex_validate_filter.lst", vocab, length)

idx_to_vocab = {values:keys for keys, values in vocab.items()}
# Out:
# Skipped :
# Skipped :

# %%
print(f"Total Unique symbols: {len(frequency)}")
print(f"Total Unique symbols in vocablary: {len(vocab)}")
# Out:
# Total Unique symbols: 547
# Total Unique symbols in vocablary: 444

# %% [markdown]
# As we'll go futher, you'll realize remaining symbols will be replaced with UNK token.
#
# We added 3 more tokens here i.e., SOS that is start of the statement, EOS that is end of the statement and PAD that will be used to pad that statements to the length of max_len of statement in the batch

# %% [markdown]
# # Load required libraries

# %%
# !pip install -q albumentations==0.4.5
# Out:
#      |████████████████████████████████| 122kB 8.2MB/s
#      |████████████████████████████████| 634kB 33.6MB/s
#   Building wheel for albumentations (setup.py) ... done
#   Building wheel for imgaug (setup.py) ... done

# %%
import cv2
import time

import albumentations as A
from albumentations.pytorch import ToTensorV2

import torch
import torch.nn as nn
from torch.nn import init

import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

from tqdm import tqdm_notebook

def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(42)

# %% [markdown]
# # Dataloader

# %% [markdown]
# Dataloader loads the data in batches, preparing for the model.
#
# Here we resized every image to a specific size.
#
# We tokenized the formulas and numericalized  i.e., replaced the characters with the respective number from the vocab.
#
# Then SOS and EOS tokens were added in the begining and ending of the sentence.
#
# After the batches are formed, formulas's lengths won't be the same throughout the batch. So, we padded them batch wise. For this we used collate_fn (checkout collate class for the implementation)

# %%
def train_augmentaions(img_size = (150,150)):
      return A.Compose([
              A.Resize(height=img_size[0], width=img_size[1], p=1), #Resizing every image to same img_size
              A.Normalize(),
              ToTensorV2(p=1.0),                  
          ], p=1.0)

class DatasetGenerator(Dataset):
    def __init__(self, array, vocab, transforms):

        self.array = array
        self.vocab = vocab
        self.transforms = transforms

    def __getitem__(self, index):
        data = self.array[index]
        img_name, formula = data

        img = cv2.imread(f"{DATA_DIR}/formula_images_processed/{img_name}")
  
        if self.transforms:
          sample = {'image': img}
          sample = self.transforms(**sample)
          img = sample['image']

        numeralised_formula = [self.vocab[SOS_TOKEN]] + self.get_vector(formula) + [self.vocab[EOS_TOKEN]] #Appending start and end token

        return img, torch.tensor(numeralised_formula)

    def __len__(self):
        return len(self.array)

    def get_vector(self, formulas):
        return ([self.vocab[each_word] if each_word in self.vocab else self.vocab[UNK_TOKEN]for each_word in formulas.split()]) #UNK token if word not in vocab

class Collate:
    def __init__(self, pad_idx):
        self.pad_idx = pad_idx

    def __call__(self, batch):
        imgs = [item[0].unsqueeze(0) for item in batch]
        imgs = torch.cat(imgs, dim=0)
        targets = [item[1] for item in batch]
        targets = pad_sequence(targets, batch_first=True, padding_value=self.pad_idx) # Padding so that sequence length is consistant in a batch

        return imgs, targets

# %% [markdown]
# # Model

# %% [markdown]
# Basically it's the architecture described in the research paper.
#
# We implemented a cnn that will give the image's features. Now, before passing them to seq decoder like we do in image caption papers, we used rnn encoder that re eoncoded each row of the grid from cnn output.
#
# We used bidirectional lstm with 256 hidden state size.
#
# Then the output is passed to decoder class which uses lstm with 512 hidden state size. Used 80 size for embedding for text.

# %%
class Encoder(nn.Module):
  
  def __init__(self, rnn_embed_size=256, n_layer=1):
    super(Encoder, self).__init__()
    
    INIT = 1e-2
    self.cnn = nn.Sequential(
        
        nn.Conv2d(in_channels = 3, out_channels = 512, kernel_size = (3,3), stride = (1,1), padding=(0,0)),
        nn.BatchNorm2d(512),
        nn.ReLU(),

        nn.Conv2d(in_channels = 512, out_channels = 512, kernel_size = (3,3), stride = (1,1), padding = (1,1)),
        nn.BatchNorm2d(512),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = (1,2), stride = (1,2), padding = (0,0)),

        nn.Conv2d(in_channels = 512, out_channels = 256, kernel_size = (3,3), stride = (1,1), padding = (1,1)),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = (2,1), stride = (2,1), padding = (0,0)),

        nn.Conv2d(in_channels = 256, out_channels = 256, kernel_size = (3,3), stride = (1,1), padding = (1,1)),
        nn.BatchNorm2d(256),
        nn.ReLU(),

        nn.Conv2d(in_channels = 256, out_channels = 128, kernel_size = (3,3), stride = (1,1), padding = (1,1)),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = (2,2), stride = (2,2), padding = (0,0)),

        nn.Conv2d(in_channels = 128, out_channels = 64, kernel_size = (3,3), stride = (1,1), padding = (1,1)),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = (2,2), stride = (2,2), padding = (1,1)),
    )

    #For Row Encoder hidden layer
    self.hidden_layer_h = nn.Parameter(torch.Tensor(n_layer*2, rnn_embed_size))
    self.hidden_layer_c = nn.Parameter(torch.Tensor(n_layer*2, rnn_embed_size))

    #To aviod random initialization
    init.uniform_(self.hidden_layer_h, -INIT, INIT)
    init.uniform_(self.hidden_layer_c, -INIT, INIT)

    self.rnn = nn.LSTM(64, rnn_embed_size, bidirectional=True, batch_first=True)
  
  def forward(self, images):
    embedded_images = self.cnn(images) #[B, C, H, W] 
    embedded_images = embedded_images.permute(0, 2, 3, 1) #[B, H, W, C]

    B, H, W, C = embedded_images.size() # B 13 13 64

    embedded_images = embedded_images.contiguous().view(B*H, W, C)

    init_hidden_layer_h = self.hidden_layer_h.unsqueeze(1).expand(-1, B*H, -1).contiguous() #[B, 26, 256]
    init_hidden_layer_c = self.hidden_layer_c.unsqueeze(1).expand(-1, B*H, -1).contiguous()

    init_hidden_layer = (init_hidden_layer_h, init_hidden_layer_c)
    
    output, (hidden_layer_h,hidden_layer_c) = self.rnn(embedded_images, init_hidden_layer) #[26,13,512]

    output = output.view(B, H, W, -1) #[B,2,13,512]

    hidden_layer_h = hidden_layer_h.view(2, B, H, -1) #[B,2,13,256]
    hidden_layer_c = hidden_layer_c.view(2, B, H, -1)

    return output, (hidden_layer_h, hidden_layer_c)

# %%
class Decoder(nn.Module):

    def __init__(self, embed_size=80, hidden_size=512,rnn_embed_size=256, vocab_size=len(vocab), num_layers=1):
        super(Decoder, self).__init__()

        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.rnn = nn.LSTMCell(embed_size+rnn_embed_size, hidden_size)
        self.linear_connector = nn.Linear(hidden_size+rnn_embed_size*2, rnn_embed_size)
        self.final = nn.Linear(rnn_embed_size, vocab_size)
        self.linear_connector2 = nn.Linear(hidden_size, rnn_embed_size)
        

    def forward(self, feature, text,last_hidden):
        qw=feature
        
        features = feature.mean(dim=[1, 2]) # [B, 512]
        
        h, c = last_hidden

        h = h.permute(1, 2, 0, 3).contiguous() #[B,13,2,256]
        h = h.view(h.size(0), h.size(1), -1) #[B, 13, 512] since rnn_embed_size = 256 and rnn_decoder = 512 
        h = h.mean(dim=1) # [B, 512]

        c = c.permute(1, 2, 0, 3).contiguous() #[B,13,2,256]
        c = c.view(c.size(0), c.size(1), -1) #[B, 13, 512] since rnn_embed_size = 256 and rnn_decoder = 512 
        c = c.mean(dim=1) # [B, 512]

        features = self.linear_connector(torch.cat([h, features], dim=1)) #[B, 256] Used this to scale back encoder output to 256. added "h" to preserve features
        
        batch_max_len = text.size(1)

        res = list()

        for t in range(batch_max_len):
          current_text = text[:, t:t+1] 

          prev_y = self.embedding(current_text).squeeze(1) #[B, 80]
          input = torch.cat([prev_y, features], dim=1)  # [B, 80+256]

          h_t, c_t = self.rnn(input, (h,c))
    
          caat = self.linear_connector2(h_t).tanh()

          output = self.final(caat)

          logit = F.softmax(output, dim=1)
          res.append(logit)

        res = torch.stack(res, dim=1)

        return res

# %%
class Model(nn.Module):
  def __init__(self):
    super(Model, self).__init__()

    self.encoder = Encoder()
    self.decoder = Decoder()

  def forward(self, images, text):

    outputs,hidden_states = self.encoder(images)
    logits = self.decoder(outputs,text,hidden_states)
    
    return logits

# %% [markdown]
# # Config

# %%
class Config:

  num_workers=4
  batch_size=16

  n_epoches=1000

  lr = 0.0003

  patience=5 # Early stopping
  
  SchedulerClass = torch.optim.lr_scheduler.ReduceLROnPlateau
  scheduler_params = dict(
      mode='min',
      factor=0.8,
      patience=1,
      verbose=True, 
      threshold=0.0001,
      threshold_mode='abs',
      cooldown=0, 
      min_lr=1e-8,
      eps=1e-08
  )

# %% [markdown]
# # Engine

# %% [markdown]
# This is the engine or trainer. It'll start the training process.
#
# We used adam as optimizer, CrossEntropy as loss function, and ReducedLRonPlateau as LR scheduler

# %%
train_loss=dict()
valid_loss=dict()

class Engine:
    
    def __init__(self,device,config,model, weight_path='./'):
  
        self.device=device
        self.config=config
        self.best_score=0
        self.best_loss=5000
        self.weight_path = weight_path

        self.model = model
        
        param_optimizer = list(self.model.named_parameters())
        no_decay = ['bias', 'LayerNorm.bias', 'LayerNorm.weight']
        optimizer_grouped_parameters = [
            {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 'weight_decay': 0.001},
            {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
        ] 
        
        self.optimizer = torch.optim.AdamW(optimizer_grouped_parameters, lr=config.lr)

        self.scheduler = config.SchedulerClass(self.optimizer, **config.scheduler_params)
        
        self.criterion = nn.CrossEntropyLoss().to(self.device)
        
    def fit(self,train_loader,validation_loader):
        for epoch in range(self.config.n_epoches):

            print("Training Started...")
            t=time.time()
            summary_loss = self.train_one_epoch(train_loader)
            train_loss[epoch] = summary_loss.avg

            print('Train : Epoch {:03}: | Summary Loss: {:.3f} | Training time: {}'.format(epoch,summary_loss.avg,time.time() - t))
            
            t=time.time()
            print("Validation Started...")
            summary_loss = self.validation(validation_loader)
            valid_loss[epoch] = summary_loss.avg

            print('Valid : Epoch {:03}: | Summary Loss: {:.3f} | Training time: {}'.format(epoch,summary_loss.avg,time.time() - t))
            
            self.scheduler.step(metrics=summary_loss.avg)
            
            if not self.best_score:
                self.best_score = summary_loss.avg  # So any validation roc_auc we have is the best one for now
                print('Saving model with best val as {}'.format(self.best_score))
                self.model.eval()   
                patience = self.config.patience
                torch.save({'model_state_dict': self.model.state_dict(),'best_score': self.best_score, 'epoch': epoch},  f"{self.weight_path}/_DD.pt")
                continue  

            if summary_loss.avg <= self.best_score:
                self.best_score = summary_loss.avg
                patience = self.config.patience  # Resetting patience since we have new best validation accuracy
                print('Imporved model with best val as {}'.format(self.best_score))
                torch.save({'model_state_dict': self.model.state_dict(),'best_score': self.best_score, 'epoch': epoch},  f"{self.weight_path}/_DD.pt")
            else:
                patience -= 1
                print('Patience Reduced')
                if patience == 0:
                    print('Early stopping. Best Val roc_auc: {:.3f}'.format(self.best_score))
                    break
                    
    def validation(self, val_loader):
        self.model.eval()

        summary_loss = AverageMeter()

        t = time.time()

        for steps,(images, formulas) in enumerate(tqdm_notebook(val_loader)):
            with torch.no_grad():
                formulas = formulas.to(self.device, dtype=torch.long)
                batch_size = images.shape[0]               
                images = images.to(self.device, dtype=torch.float32)

                logits = self.model(images, formulas)
                
                padding = torch.ones_like(formulas) * vocab[PAD_TOKEN]
                mask = (formulas != padding)

                formulas = formulas.masked_select(mask)
                logits = logits.masked_select(mask.unsqueeze(2).expand(-1, -1, logits.size(2))).contiguous().view(-1, logits.size(2))

                loss = self.criterion(logits, formulas)

                summary_loss.update(loss.detach().item(), batch_size)

        return summary_loss


    def train_one_epoch(self, train_loader):
        self.model.train()

        summary_loss = AverageMeter()

        t = time.time()

        for steps,(images, formulas) in enumerate(tqdm_notebook(train_loader)):
            formulas = formulas.to(self.device, dtype=torch.long)
            batch_size = images.shape[0]               
            images = images.to(self.device, dtype=torch.float32)

            self.optimizer.zero_grad()

            logits = self.model(images, formulas)

            padding = torch.ones_like(formulas) * vocab[PAD_TOKEN]
            mask = (formulas != padding)

            formulas = formulas.masked_select(mask)
            logits = logits.masked_select(mask.unsqueeze(2).expand(-1, -1, logits.size(2))).contiguous().view(-1, logits.size(2))

            loss = self.criterion(logits, formulas)

            loss.backward()
            self.optimizer.step()

            summary_loss.update(loss.detach().item(), batch_size)

        return summary_loss

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # Driver

# %%
train_dataset = DatasetGenerator(train_data, vocab, transforms=train_augmentaions())
valid_dataset = DatasetGenerator(valid_data, vocab, transforms=train_augmentaions())

train_loader = torch.utils.data.DataLoader(
          train_dataset,
          batch_size=Config.batch_size,
          collate_fn=Collate(vocab[PAD_TOKEN]),
          pin_memory=True,
          drop_last=True,
          num_workers=Config.num_workers,
      )

validation_loader = torch.utils.data.DataLoader(
          valid_dataset, 
          batch_size=Config.batch_size,
          num_workers=Config.num_workers,
          pin_memory=False,
          collate_fn=Collate(vocab[PAD_TOKEN]),
      ) 

model = Model().cuda()

engine = Engine(device=torch.device('cuda'), config=Config,model=model)
engine.fit(train_loader, validation_loader)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training Started...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:103: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=4704.0), HTML(value='')))
# Train : Epoch 000: | Summary Loss: 5.257 | Training time: 3503.783320426941
# Validation Started...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=524.0), HTML(value='')))
# Valid : Epoch 000: | Summary Loss: 5.106 | Training time: 133.23440146446228
# Saving model with best val as 5.106474088967345
# Training Started...
# HBox(children=(FloatProgress(value=0.0, max=4704.0), HTML(value='')))
# Train : Epoch 001: | Summary Loss: 5.103 | Training time: 3513.107255220413
# Validation Started...
# HBox(children=(FloatProgress(value=0.0, max=524.0), HTML(value='')))
# Valid : Epoch 001: | Summary Loss: 5.101 | Training time: 131.6291527748108
# Imporved model with best val as 5.100928452422257
# Training Started...
# HBox(children=(FloatProgress(value=0.0, max=4704.0), HTML(value='')))

# %% [markdown]
# * Train : Epoch 000: | Summary Loss: 5.257 | Training time: 3503.783320426941
#
#
# * Valid : Epoch 000: | Summary Loss: 5.106 | Training time: 133.23440146446228
#
# Saving model with best val as 5.106474088967345
#
#
#
# * Train : Epoch 001: | Summary Loss: 5.103 | Training time: 3513.107255220413
#
#
# * Valid : Epoch 001: | Summary Loss: 5.101 | Training time: 131.6291527748108
#
# Imporved model with best val as 5.100928452422257

# %% [markdown]
# Basically loss is reducing so our model is learning.
#
# Due to hardware constraints, it's not feasable to train this model. It took one hour for one epoch and colab disconnects after some hours as seen in the image.
#
# But the next step is simple.
#
# * Just train the model to its full potential and finetune the model via hyperparameter tuning and different training configs.
# * Evaulate the model on test data. BLEU metric is suitable here. It's for evaluating a generated sentence to a reference sentence. Scores from 0.0-1.0 or 0-100
# * Once satisfied with the results, can wrap up with flask to setup up a REST api and deploy it with an nginx server on any cloud service as per the needs.

# %% [markdown]
# For the graph visualization, the below code snippet can be used after the training is completed.

# %%
import matplotlib.pyplot as plt

plt.plot(list(train_loss.keys()), list(train_loss.values()), linewidth=1, label="Train")
plt.plot(list(valid_loss.keys()), list(valid_loss.values()),  linewidth=1, label="Validation")
plt.suptitle('Fold : 0 ')
plt.xlabel('Epoches')
plt.ylabel('Loss (Log scale)')
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.show()
